# %% [markdown]
# <a href="https://colab.research.google.com/github/MahlaMirali/MachineLearning_Lentil_Seed_Coat_Colour_and_Phenolics/blob/master/Copy_of_ML_4colour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries/ file

# %%
# !pip install pandas==1.0.3

# %%
from google.colab import files
import io
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
import numpy as np
from scipy import sparse
from collections import Counter
import itertools
from random import sample
import scipy
from scipy import stats
from scipy.stats import chi2_contingency
from pprint import pprint


#ML from sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier

# ANN
import tensorflow
import keras
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
from keras.utils import np_utils
from keras.optimizers import Adam

# %% [markdown]
# **Upload/import the file**

# %%
# upload the file into google colab
uploaded = files.upload()

# %%
# import the file into a dataframe
df = pd.read_csv(io.BytesIO(uploaded['ML_4colour.csv']))
# drop the rows with missing data
df = df.drop(df[(df.cat == 0)| (df['1748.2'] == 0)].index)
print(len(df))
# omitting some of the columns
df = df.drop(['Folder','genotypes','location','rep',
                         '4_sal','4_coum','3_cinn','cat_13C'], axis = 1)
df.head(5)
# Out:
# 190
#     hull cotyledon  vanil_4gluc  ...   1509.2I  1509.2II    1525.1
# 0  brown       red     0.246700  ...  1.209678  0.451232  0.716158
# 1  brown       red     0.231851  ...  1.461536  0.538614  0.848644
# 2  brown       red     0.293519  ...  1.152952  0.539029  0.919429
# 4  brown       red     0.164049  ...  1.620385  0.953261  1.043973
# 5  brown       red     0.231600  ...  2.116371  0.879104  1.177969
#
# [5 rows x 93 columns]

# %% [markdown]
# # EDA

# %%
# histogram
hist = df.hist(figsize = (15,20))

# %%
# Correlation

# Compute the correlation matrix 
correlation_matrix = df.drop('hull', axis=1).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(correlation_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Plot some of the features
df_new = df.rename(columns={'cat':'Catechin', 'cat_gluc': 'Catechin gluc','lut_4gluc':'Luteolin gluc',
                            '595.6I' : 'GC dimer'})
x = df_new.drop(['hull'], axis = 1) 
y= df_new['hull']
sns.set_context('talk')
grid = sns.PairGrid(data=df_new,hue = 'hull', 
                  vars = ['Catechin gluc','Catechin','Luteolin gluc','GC dimer','B2'],
                  palette={ 0: 'brown',1: 'green', 2 : 'grey', 3: 'tan' },height =1.7)
grid = grid.map_upper(plt.scatter, edgecolor = 'k')
grid = grid.map_diag(plt.hist, bins = 10, edgecolor = 'k')
grid = grid.map_lower(sns.kdeplot)
grid.savefig('pairgrid.png',  dpi=400)
fig.show()
files.download('pairgrid.png')

# %%
# PCA 

df_x = df.drop(['hull', 'cotyledon'], axis = 1)
color = df['hull'].tolist()
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(np.array(df_x))
pdf = pd.DataFrame(data = principalComponents
             , columns = ['one', 'two'])
a = pdf['one'].tolist()
b = pdf['two'].tolist()
plt.figure(figsize=(10,7))
plt.scatter(a,b, alpha=1, c = color)
plt.axis([-600, 600, -40, 40])
# Out:
# (-600.0, 600.0, -40.0, 40.0)

# %% [markdown]
# # Functions

# %%
def OHE_Y(df):
    y = np.asarray(df[['hull']])
    y = y.reshape(len(y),)
    label_encoder_y = LabelEncoder()
    label_encoder_y = label_encoder_y.fit(y)
    encoded_y = label_encoder_y.transform(y)
    return encoded_y

#plots a neat confusion matrix
def pretty_print_conf_matrix(y_true, y_pred, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label', fontsize=12)
    plt.xlabel('Predicted label', fontsize=12)
    if normalize:
        cm = np.round(cm.astype('float') / cm.sum(),2) 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],horizontalalignment="center",color="white" if cm[i, j] > thresh else "black",
                 fontsize=12)
        
def model_fit(model, df):
    df_x = df.drop(['hull', 'cotyledon'], axis = 1)
    y = OHE_Y(df)
    x = np.asarray(df_x)
    scaler = MinMaxScaler(feature_range=(0, 1)) 
    x = scaler.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.8, test_size = 0.2, random_state = 100)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    x_pred = model.predict(x_train)
    pretty_print_conf_matrix(y_pred, y_test, classes= ['Brown', 'Green', 'Grey', 'Tan'],
                            normalize=False, title='Confusion Matrix')
    print(classification_report(y_test, y_pred))
    return x_train, x_train, x_test, y_train, y_test

# %% [markdown]
# # Model # 1: RF

# %%
x_train, x_test, y_train, y_test = model_fit(RandomForestClassifier(), df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.78      0.67         9
#            1       0.75      0.75      0.75         8
#            2       0.73      0.80      0.76        10
#            3       0.71      0.45      0.56        11
#
#     accuracy                           0.68        38
#    macro avg       0.69      0.70      0.68        38
# weighted avg       0.69      0.68      0.68        38

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [10, 40],
    'max_features': [30, 70],
    'min_samples_leaf': [4,8],
    'min_samples_split': [8,  12],
    'n_estimators': [50, 200, 600]
}
# Create a based model
grid_search = GridSearchCV(estimator = model, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
grid_search.best_params_
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:  2.1min finished
# {'bootstrap': True, 'max_depth': 10, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 600}

# %%
x_train, x_test, y_train, y_test = model_fit(RandomForestClassifier(bootstrap= True, max_depth= 10, max_features= 30, min_samples_leaf= 4,
                                 min_samples_split= 8, n_estimators= 600), df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74         9
#            1       0.75      0.75      0.75         8
#            2       0.78      0.70      0.74        10
#            3       0.64      0.64      0.64        11
#
#     accuracy                           0.71        38
#    macro avg       0.72      0.72      0.72        38
# weighted avg       0.71      0.71      0.71        38

# %% [markdown]
# ### Does PCA help?

# %%
n_components = [10, 20, 40]
for i in n_components:
  print('\n', 'n_component = ', i)
  pca = PCA(n_components=i)
  principalComponents = pca.fit_transform(np.array(df_x))
  model= RandomForestClassifier(bootstrap= True, max_depth= 10, max_features= 30, min_samples_leaf= 4,
                                min_samples_split= 8, n_estimators= 600)
  x_train, x_test, y_train, y_test = train_test_split(principalComponents,y, train_size = 0.8, test_size = 0.2, random_state = 100)
  model.fit(x_train, y_train)
  y_pred = model.predict(x_test)
  pretty_print_conf_matrix(y_pred, y_test, classes= ['red', 'green', 'gray', 'brown'],
                          normalize=False, title='Confusion Matrix')
  plt.show()
  print(classification_report(y_test, y_pred))
# Out:
#  n_component =  10
#               precision    recall  f1-score   support
#
#            0       0.58      0.78      0.67         9
#            1       0.71      0.62      0.67         8
#            2       0.60      0.60      0.60        10
#            3       0.56      0.45      0.50        11
#
#     accuracy                           0.61        38
#    macro avg       0.61      0.61      0.61        38
# weighted avg       0.61      0.61      0.60        38
#
#
#  n_component =  20
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.71      0.62      0.67         8
#            2       0.60      0.60      0.60        10
#            3       0.50      0.45      0.48        11
#
#     accuracy                           0.58        38
#    macro avg       0.59      0.59      0.59        38
# weighted avg       0.58      0.58      0.58        38
#
#
#  n_component =  40
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60         9
#            1       0.71      0.62      0.67         8
#            2       0.60      0.60      0.60        10
#            3       0.50      0.45      0.48        11
#
#     accuracy                           0.58        38
#    macro avg       0.59      0.59      0.59        38
# weighted avg       0.58      0.58      0.58        38

# %% [markdown]
# # **Model # 2 : KNN**

# %% [markdown]
# ## Before tuning

# %%
x_train, x_test, y_train, y_test = model_fit(KNeighborsClassifier(), df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.44      0.44         9
#            1       0.57      0.50      0.53         8
#            2       0.55      0.60      0.57        10
#            3       0.55      0.55      0.55        11
#
#     accuracy                           0.53        38
#    macro avg       0.53      0.52      0.52        38
# weighted avg       0.53      0.53      0.53        38

# %% [markdown]
# ## Hyperparameters tuning

# %%
model = KNeighborsClassifier()
param_grid = {
    'n_neighbors': [3, 5,10,20, 50], 
    'weights': [ 'uniform', 'distance'], 
    'metric': ['euclidean', 'manhattan','minkowski']}
# Create a based model
grid_search = GridSearchCV(model, param_grid = param_grid, cv = 5)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
print(grid_search.best_params_)
# Out:
# {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}

# %%
 x_train, x_test, y_train, y_test = model_fit(KNeighborsClassifier(metric= 'manhattan', n_neighbors=5, weights= 'distance'), df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.44      0.53         9
#            1       0.50      0.50      0.50         8
#            2       0.55      0.60      0.57        10
#            3       0.62      0.73      0.67        11
#
#     accuracy                           0.58        38
#    macro avg       0.58      0.57      0.57        38
# weighted avg       0.58      0.58      0.57        38

# %% [markdown]
# # **Model # 3 : SVM**

# %% [markdown]
# **Original Model**

# %%
x_train, x_test, y_train, y_test = model_fit(SVC(), df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.63         9
#            1       0.86      0.75      0.80         8
#            2       0.62      0.80      0.70        10
#            3       0.64      0.64      0.64        11
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.69      0.69        38
# weighted avg       0.70      0.68      0.68        38

# %% [markdown]
# **Hyperparameters tuning**

# %%
# kernel = rbf
model = SVC()
param_grid = {
    'C': [ 0.1, 1, 10], 
    'gamma': [  0.1,0.01,0.001], # for rbf
    'kernel': ['rbf', 'poly'],
    'degree': [1,2,3]
}
# Create a based model
grid_search = GridSearchCV(model, param_grid = param_grid, cv = 5, n_jobs = -1, verbose = 2)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# {'C': 10, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:    1.1s finished

# %%
x_train, x_test, y_train, y_test =  model_fit(SVC(C= 10, gamma= 0.01, kernel= 'rbf', degree = 1), df)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67         9
#            1       0.86      0.75      0.80         8
#            2       0.62      0.80      0.70        10
#            3       0.67      0.73      0.70        11
#
#     accuracy                           0.71        38
#    macro avg       0.74      0.71      0.71        38
# weighted avg       0.73      0.71      0.71        38

# %% [markdown]
# # **Model # 4 : Neural Network**

# %%
lrs = [ 0.01, 0.001, 0.0001]
batch_sizes = [16, 32, 64]
epoch =200
for lr in lrs:
  for batch_size in batch_sizes:
    model=Sequential()
    model.add(Dense(200,input_dim=91,activation='relu')) # input dimention
    model.add(Dropout(0.3))
    model.add(Dense(100,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(30,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(4,activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy',optimizer=Adam(lr= lr),metrics=['accuracy'])
    #model.summary()
    history = model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size= batch_size,epochs = epoch ,verbose=0)
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    pyplot.show()
    scores = model.evaluate(x_test, y_test, verbose=0)
    print('learning rate = ', lr, 'batch =', batch_size, "Accuracy: %.2f%%" % (scores[1]*100), '\n', '\n')
# Out:
# learning rate =  0.01 batch = 16 Accuracy: 76.32%
# learning rate =  0.01 batch = 32 Accuracy: 76.32%
# learning rate =  0.01 batch = 64 Accuracy: 71.05%
# learning rate =  0.001 batch = 16 Accuracy: 73.68%
# learning rate =  0.001 batch = 32 Accuracy: 76.32%
# learning rate =  0.001 batch = 64 Accuracy: 71.05%
# learning rate =  0.0001 batch = 16 Accuracy: 78.95%
# learning rate =  0.0001 batch = 32 Accuracy: 71.05%
# learning rate =  0.0001 batch = 64 Accuracy: 76.32%

# %%
lrs = [ 0.0001]
batch_sizes = [16]
epoch =130
for lr in lrs:
  for batch_size in batch_sizes:
    model=Sequential()
    model.add(Dense(200,input_dim=91,activation='relu')) # input dimention
    model.add(Dropout(0.3))
    model.add(Dense(100,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(30,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(4,activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy',optimizer=Adam(lr= lr),metrics=['accuracy'])
    #model.summary()
    history = model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size= batch_size,epochs = epoch ,verbose=2)
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='test')
    pyplot.legend()
    pyplot.show()
    scores = model.evaluate(x_test, y_test, verbose=0)
    print('learning rate = ', lr, 'batch =', batch_size, "Accuracy: %.2f%%" % (scores[1]*100), '\n', '\n')
# Out:
# Train on 152 samples, validate on 38 samples
# Epoch 1/130
#  - 0s - loss: 1.4321 - accuracy: 0.2039 - val_loss: 1.3819 - val_accuracy: 0.2632
# Epoch 2/130
#  - 0s - loss: 1.4313 - accuracy: 0.2039 - val_loss: 1.3773 - val_accuracy: 0.2632
# Epoch 3/130
#  - 0s - loss: 1.3664 - accuracy: 0.2697 - val_loss: 1.3743 - val_accuracy: 0.3158
# Epoch 4/130
#  - 0s - loss: 1.3774 - accuracy: 0.2697 - val_loss: 1.3726 - val_accuracy: 0.3158
# Epoch 5/130
#  - 0s - loss: 1.3961 - accuracy: 0.2303 - val_loss: 1.3706 - val_accuracy: 0.3158
# Epoch 6/130
#  - 0s - loss: 1.3818 - accuracy: 0.2632 - val_loss: 1.3668 - val_accuracy: 0.2895
# Epoch 7/130
#  - 0s - loss: 1.3612 - accuracy: 0.3487 - val_loss: 1.3641 - val_accuracy: 0.2368
# Epoch 8/130
#  - 0s - loss: 1.3698 - accuracy: 0.2961 - val_loss: 1.3661 - val_accuracy: 0.2105
# Epoch 9/130
#  - 0s - loss: 1.3703 - accuracy: 0.2697 - val_loss: 1.3626 - val_accuracy: 0.2368
# Epoch 10/130
#  - 0s - loss: 1.3506 - accuracy: 0.3026 - val_loss: 1.3592 - val_accuracy: 0.2368
# Epoch 11/130
#  - 0s - loss: 1.3639 - accuracy: 0.2697 - val_loss: 1.3553 - val_accuracy: 0.2368
# Epoch 12/130
#  - 0s - loss: 1.3885 - accuracy: 0.2368 - val_loss: 1.3517 - val_accuracy: 0.2632
# Epoch 13/130
#  - 0s - loss: 1.3174 - accuracy: 0.3684 - val_loss: 1.3481 - val_accuracy: 0.2895
# Epoch 14/130
#  - 0s - loss: 1.3249 - accuracy: 0.4145 - val_loss: 1.3449 - val_accuracy: 0.2895
# Epoch 15/130
#  - 0s - loss: 1.3316 - accuracy: 0.3289 - val_loss: 1.3412 - val_accuracy: 0.2895
# Epoch 16/130
#  - 0s - loss: 1.3212 - accuracy: 0.3421 - val_loss: 1.3345 - val_accuracy: 0.3421
# Epoch 17/130
#  - 0s - loss: 1.3190 - accuracy: 0.3289 - val_loss: 1.3301 - val_accuracy: 0.3421
# Epoch 18/130
#  - 0s - loss: 1.3264 - accuracy: 0.3684 - val_loss: 1.3247 - val_accuracy: 0.3684
# Epoch 19/130
#  - 0s - loss: 1.3179 - accuracy: 0.3289 - val_loss: 1.3195 - val_accuracy: 0.3684
# Epoch 20/130
#  - 0s - loss: 1.3159 - accuracy: 0.3684 - val_loss: 1.3190 - val_accuracy: 0.3421
# Epoch 21/130
#  - 0s - loss: 1.3342 - accuracy: 0.3750 - val_loss: 1.3136 - val_accuracy: 0.3421
# Epoch 22/130
#  - 0s - loss: 1.3171 - accuracy: 0.3553 - val_loss: 1.3111 - val_accuracy: 0.3421
# Epoch 23/130
#  - 0s - loss: 1.3110 - accuracy: 0.4013 - val_loss: 1.3034 - val_accuracy: 0.3421
# Epoch 24/130
#  - 0s - loss: 1.2931 - accuracy: 0.3684 - val_loss: 1.2946 - val_accuracy: 0.4211
# Epoch 25/130
#  - 0s - loss: 1.3066 - accuracy: 0.4539 - val_loss: 1.2878 - val_accuracy: 0.4211
# Epoch 26/130
#  - 0s - loss: 1.2852 - accuracy: 0.4145 - val_loss: 1.2804 - val_accuracy: 0.4474
# Epoch 27/130
#  - 0s - loss: 1.2811 - accuracy: 0.4605 - val_loss: 1.2752 - val_accuracy: 0.4737
# Epoch 28/130
#  - 0s - loss: 1.2792 - accuracy: 0.4605 - val_loss: 1.2699 - val_accuracy: 0.4737
# Epoch 29/130
#  - 0s - loss: 1.2566 - accuracy: 0.4276 - val_loss: 1.2634 - val_accuracy: 0.4474
# Epoch 30/130
#  - 0s - loss: 1.2473 - accuracy: 0.4539 - val_loss: 1.2586 - val_accuracy: 0.4474
# Epoch 31/130
#  - 0s - loss: 1.2921 - accuracy: 0.3947 - val_loss: 1.2523 - val_accuracy: 0.4474
# Epoch 32/130
#  - 0s - loss: 1.2461 - accuracy: 0.4474 - val_loss: 1.2486 - val_accuracy: 0.4737
# Epoch 33/130
#  - 0s - loss: 1.2306 - accuracy: 0.4671 - val_loss: 1.2456 - val_accuracy: 0.4737
# Epoch 34/130
#  - 0s - loss: 1.2372 - accuracy: 0.5066 - val_loss: 1.2371 - val_accuracy: 0.4737
# Epoch 35/130
#  - 0s - loss: 1.2410 - accuracy: 0.5132 - val_loss: 1.2328 - val_accuracy: 0.5000
# Epoch 36/130
#  - 0s - loss: 1.2200 - accuracy: 0.4671 - val_loss: 1.2305 - val_accuracy: 0.5000
# Epoch 37/130
#  - 0s - loss: 1.2276 - accuracy: 0.4671 - val_loss: 1.2306 - val_accuracy: 0.5000
# Epoch 38/130
#  - 0s - loss: 1.2310 - accuracy: 0.4276 - val_loss: 1.2263 - val_accuracy: 0.5000
# Epoch 39/130
#  - 0s - loss: 1.2056 - accuracy: 0.5132 - val_loss: 1.2243 - val_accuracy: 0.5000
# Epoch 40/130
#  - 0s - loss: 1.1855 - accuracy: 0.4868 - val_loss: 1.2231 - val_accuracy: 0.5000
# Epoch 41/130
#  - 0s - loss: 1.1973 - accuracy: 0.5000 - val_loss: 1.2217 - val_accuracy: 0.5000
# Epoch 42/130
#  - 0s - loss: 1.1995 - accuracy: 0.5395 - val_loss: 1.2184 - val_accuracy: 0.5000
# Epoch 43/130
#  - 0s - loss: 1.1674 - accuracy: 0.5789 - val_loss: 1.2129 - val_accuracy: 0.5000
# Epoch 44/130
#  - 0s - loss: 1.1857 - accuracy: 0.5855 - val_loss: 1.2093 - val_accuracy: 0.5263
# Epoch 45/130
#  - 0s - loss: 1.1959 - accuracy: 0.5066 - val_loss: 1.2015 - val_accuracy: 0.5263
# Epoch 46/130
#  - 0s - loss: 1.1486 - accuracy: 0.5658 - val_loss: 1.1979 - val_accuracy: 0.5526
# Epoch 47/130
#  - 0s - loss: 1.1556 - accuracy: 0.5395 - val_loss: 1.1895 - val_accuracy: 0.6053
# Epoch 48/130
#  - 0s - loss: 1.1457 - accuracy: 0.6382 - val_loss: 1.1892 - val_accuracy: 0.6579
# Epoch 49/130
#  - 0s - loss: 1.1669 - accuracy: 0.4934 - val_loss: 1.1808 - val_accuracy: 0.6053
# Epoch 50/130
#  - 0s - loss: 1.1243 - accuracy: 0.5855 - val_loss: 1.1766 - val_accuracy: 0.6053
# Epoch 51/130
#  - 0s - loss: 1.1185 - accuracy: 0.5592 - val_loss: 1.1726 - val_accuracy: 0.6579
# Epoch 52/130
#  - 0s - loss: 1.1522 - accuracy: 0.5658 - val_loss: 1.1657 - val_accuracy: 0.6579
# Epoch 53/130
#  - 0s - loss: 1.1149 - accuracy: 0.5592 - val_loss: 1.1624 - val_accuracy: 0.6316
# Epoch 54/130
#  - 0s - loss: 1.1289 - accuracy: 0.5855 - val_loss: 1.1623 - val_accuracy: 0.6316
# Epoch 55/130
#  - 0s - loss: 1.0880 - accuracy: 0.5461 - val_loss: 1.1603 - val_accuracy: 0.6316
# Epoch 56/130
#  - 0s - loss: 1.1205 - accuracy: 0.5789 - val_loss: 1.1552 - val_accuracy: 0.6316
# Epoch 57/130
#  - 0s - loss: 1.0589 - accuracy: 0.6118 - val_loss: 1.1513 - val_accuracy: 0.6316
# Epoch 58/130
#  - 0s - loss: 1.0916 - accuracy: 0.5789 - val_loss: 1.1456 - val_accuracy: 0.6316
# Epoch 59/130
#  - 0s - loss: 1.0833 - accuracy: 0.5789 - val_loss: 1.1435 - val_accuracy: 0.6579
# Epoch 60/130
#  - 0s - loss: 1.0731 - accuracy: 0.5724 - val_loss: 1.1425 - val_accuracy: 0.6316
# Epoch 61/130
#  - 0s - loss: 1.0555 - accuracy: 0.5855 - val_loss: 1.1390 - val_accuracy: 0.6316
# Epoch 62/130
#  - 0s - loss: 1.0451 - accuracy: 0.5987 - val_loss: 1.1361 - val_accuracy: 0.6579
# Epoch 63/130
#  - 0s - loss: 1.0635 - accuracy: 0.5658 - val_loss: 1.1313 - val_accuracy: 0.6842
# Epoch 64/130
#  - 0s - loss: 1.0704 - accuracy: 0.6184 - val_loss: 1.1295 - val_accuracy: 0.7105
# Epoch 65/130
#  - 0s - loss: 1.0358 - accuracy: 0.5987 - val_loss: 1.1302 - val_accuracy: 0.6842
# Epoch 66/130
#  - 0s - loss: 1.0181 - accuracy: 0.6316 - val_loss: 1.1270 - val_accuracy: 0.7105
# Epoch 67/130
#  - 0s - loss: 1.0317 - accuracy: 0.5987 - val_loss: 1.1195 - val_accuracy: 0.6842
# Epoch 68/130
#  - 0s - loss: 1.0009 - accuracy: 0.6053 - val_loss: 1.1158 - val_accuracy: 0.6316
# Epoch 69/130
#  - 0s - loss: 1.0246 - accuracy: 0.5987 - val_loss: 1.1122 - val_accuracy: 0.6579
# Epoch 70/130
#  - 0s - loss: 1.0167 - accuracy: 0.6711 - val_loss: 1.1051 - val_accuracy: 0.6842
# Epoch 71/130
#  - 0s - loss: 0.9798 - accuracy: 0.6711 - val_loss: 1.1003 - val_accuracy: 0.7105
# Epoch 72/130
#  - 0s - loss: 0.9512 - accuracy: 0.6382 - val_loss: 1.0967 - val_accuracy: 0.7105
# Epoch 73/130
#  - 0s - loss: 0.9533 - accuracy: 0.6776 - val_loss: 1.0943 - val_accuracy: 0.7105
# Epoch 74/130
#  - 0s - loss: 0.9248 - accuracy: 0.6908 - val_loss: 1.0912 - val_accuracy: 0.6842
# Epoch 75/130
#  - 0s - loss: 0.9394 - accuracy: 0.6579 - val_loss: 1.0871 - val_accuracy: 0.7368
# Epoch 76/130
#  - 0s - loss: 0.9100 - accuracy: 0.6908 - val_loss: 1.0800 - val_accuracy: 0.7368
# Epoch 77/130
#  - 0s - loss: 0.9276 - accuracy: 0.6579 - val_loss: 1.0773 - val_accuracy: 0.7632
# Epoch 78/130
#  - 0s - loss: 0.9127 - accuracy: 0.6974 - val_loss: 1.0768 - val_accuracy: 0.7368
# Epoch 79/130
#  - 0s - loss: 0.9181 - accuracy: 0.6711 - val_loss: 1.0743 - val_accuracy: 0.7368
# Epoch 80/130
#  - 0s - loss: 0.8976 - accuracy: 0.6842 - val_loss: 1.0763 - val_accuracy: 0.7632
# Epoch 81/130
#  - 0s - loss: 0.8574 - accuracy: 0.6908 - val_loss: 1.0730 - val_accuracy: 0.7632
# Epoch 82/130
#  - 0s - loss: 0.8718 - accuracy: 0.6974 - val_loss: 1.0672 - val_accuracy: 0.7368
# Epoch 83/130
#  - 0s - loss: 0.8895 - accuracy: 0.7105 - val_loss: 1.0647 - val_accuracy: 0.7632
# Epoch 84/130
#  - 0s - loss: 0.9249 - accuracy: 0.6382 - val_loss: 1.0633 - val_accuracy: 0.7632
# Epoch 85/130
#  - 0s - loss: 0.8436 - accuracy: 0.7237 - val_loss: 1.0589 - val_accuracy: 0.7632
# Epoch 86/130
#  - 0s - loss: 0.8164 - accuracy: 0.7434 - val_loss: 1.0512 - val_accuracy: 0.7895
# Epoch 87/130
#  - 0s - loss: 0.8577 - accuracy: 0.6908 - val_loss: 1.0540 - val_accuracy: 0.7632
# Epoch 88/130
#  - 0s - loss: 0.8301 - accuracy: 0.7237 - val_loss: 1.0432 - val_accuracy: 0.7895
# Epoch 89/130
#  - 0s - loss: 0.8239 - accuracy: 0.6908 - val_loss: 1.0411 - val_accuracy: 0.7895
# Epoch 90/130
#  - 0s - loss: 0.7984 - accuracy: 0.7237 - val_loss: 1.0409 - val_accuracy: 0.7895
# Epoch 91/130
#  - 0s - loss: 0.8127 - accuracy: 0.7171 - val_loss: 1.0398 - val_accuracy: 0.8158
# Epoch 92/130
#  - 0s - loss: 0.7921 - accuracy: 0.7303 - val_loss: 1.0356 - val_accuracy: 0.7895
# Epoch 93/130
#  - 0s - loss: 0.7819 - accuracy: 0.7237 - val_loss: 1.0369 - val_accuracy: 0.7895
# Epoch 94/130
#  - 0s - loss: 0.7878 - accuracy: 0.7632 - val_loss: 1.0305 - val_accuracy: 0.8158
# Epoch 95/130
#  - 0s - loss: 0.7748 - accuracy: 0.7500 - val_loss: 1.0285 - val_accuracy: 0.7895
# Epoch 96/130
#  - 0s - loss: 0.7826 - accuracy: 0.7697 - val_loss: 1.0319 - val_accuracy: 0.7632
# Epoch 97/130
#  - 0s - loss: 0.7660 - accuracy: 0.7237 - val_loss: 1.0294 - val_accuracy: 0.7895
# Epoch 98/130
#  - 0s - loss: 0.7563 - accuracy: 0.7829 - val_loss: 1.0285 - val_accuracy: 0.7895
# Epoch 99/130
#  - 0s - loss: 0.7859 - accuracy: 0.7237 - val_loss: 1.0239 - val_accuracy: 0.8158
# Epoch 100/130
#  - 0s - loss: 0.7763 - accuracy: 0.7105 - val_loss: 1.0265 - val_accuracy: 0.8158
# Epoch 101/130
#  - 0s - loss: 0.7771 - accuracy: 0.7237 - val_loss: 1.0202 - val_accuracy: 0.8158
# Epoch 102/130
#  - 0s - loss: 0.7340 - accuracy: 0.7763 - val_loss: 1.0207 - val_accuracy: 0.8158
# Epoch 103/130
#  - 0s - loss: 0.7420 - accuracy: 0.7763 - val_loss: 1.0244 - val_accuracy: 0.8158
# Epoch 104/130
#  - 0s - loss: 0.7383 - accuracy: 0.7632 - val_loss: 1.0233 - val_accuracy: 0.8158
# Epoch 105/130
#  - 0s - loss: 0.7404 - accuracy: 0.7171 - val_loss: 1.0286 - val_accuracy: 0.8158
# Epoch 106/130
#  - 0s - loss: 0.7434 - accuracy: 0.7697 - val_loss: 1.0132 - val_accuracy: 0.8421
# Epoch 107/130
#  - 0s - loss: 0.7359 - accuracy: 0.7434 - val_loss: 1.0176 - val_accuracy: 0.8421
# Epoch 108/130
#  - 0s - loss: 0.7144 - accuracy: 0.7829 - val_loss: 1.0233 - val_accuracy: 0.8158
# Epoch 109/130
#  - 0s - loss: 0.7217 - accuracy: 0.7500 - val_loss: 1.0211 - val_accuracy: 0.8158
# Epoch 110/130
#  - 0s - loss: 0.7479 - accuracy: 0.7763 - val_loss: 1.0153 - val_accuracy: 0.8158
# Epoch 111/130
#  - 0s - loss: 0.7207 - accuracy: 0.8026 - val_loss: 1.0139 - val_accuracy: 0.8158
# Epoch 112/130
#  - 0s - loss: 0.7173 - accuracy: 0.7697 - val_loss: 1.0142 - val_accuracy: 0.8158
# Epoch 113/130
#  - 0s - loss: 0.6743 - accuracy: 0.8026 - val_loss: 1.0146 - val_accuracy: 0.8158
# Epoch 114/130
#  - 0s - loss: 0.6973 - accuracy: 0.7697 - val_loss: 1.0149 - val_accuracy: 0.8158
# Epoch 115/130
#  - 0s - loss: 0.6803 - accuracy: 0.7961 - val_loss: 1.0117 - val_accuracy: 0.8158
# Epoch 116/130
#  - 0s - loss: 0.6982 - accuracy: 0.7961 - val_loss: 1.0136 - val_accuracy: 0.8158
# Epoch 117/130
#  - 0s - loss: 0.6988 - accuracy: 0.7632 - val_loss: 1.0089 - val_accuracy: 0.8158
# Epoch 118/130
#  - 0s - loss: 0.6890 - accuracy: 0.8026 - val_loss: 1.0075 - val_accuracy: 0.8158
# Epoch 119/130
#  - 0s - loss: 0.6281 - accuracy: 0.8158 - val_loss: 1.0112 - val_accuracy: 0.8158
# Epoch 120/130
#  - 0s - loss: 0.6792 - accuracy: 0.8355 - val_loss: 1.0104 - val_accuracy: 0.8421
# Epoch 121/130
#  - 0s - loss: 0.6160 - accuracy: 0.8355 - val_loss: 1.0078 - val_accuracy: 0.8421
# Epoch 122/130
#  - 0s - loss: 0.6392 - accuracy: 0.8092 - val_loss: 1.0149 - val_accuracy: 0.8158
# Epoch 123/130
#  - 0s - loss: 0.6207 - accuracy: 0.8224 - val_loss: 1.0194 - val_accuracy: 0.8158
# Epoch 124/130
#  - 0s - loss: 0.6633 - accuracy: 0.8026 - val_loss: 1.0135 - val_accuracy: 0.8158
# Epoch 125/130
#  - 0s - loss: 0.6509 - accuracy: 0.7697 - val_loss: 1.0085 - val_accuracy: 0.8421
# Epoch 126/130
#  - 0s - loss: 0.6602 - accuracy: 0.7697 - val_loss: 1.0142 - val_accuracy: 0.8158
# Epoch 127/130
#  - 0s - loss: 0.6613 - accuracy: 0.8158 - val_loss: 1.0148 - val_accuracy: 0.8421
# Epoch 128/130
#  - 0s - loss: 0.6337 - accuracy: 0.8158 - val_loss: 1.0185 - val_accuracy: 0.8158
# Epoch 129/130
#  - 0s - loss: 0.5820 - accuracy: 0.8618 - val_loss: 1.0208 - val_accuracy: 0.8421
# Epoch 130/130
#  - 0s - loss: 0.6501 - accuracy: 0.7829 - val_loss: 1.0149 - val_accuracy: 0.8421
# learning rate =  0.0001 batch = 16 Accuracy: 84.21%

# %%
y_pred = []
for i in model.predict(x_test):
  y_pred.append(np.argmax(i))
pretty_print_conf_matrix(y_test, y_pred, classes= ['red', 'green', 'gray', 'brown'],
                            normalize=False, title='Confusion Matrix')
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78         9
#            1       0.75      0.75      0.75         8
#            2       0.83      1.00      0.91        10
#            3       1.00      0.82      0.90        11
#
#     accuracy                           0.84        38
#    macro avg       0.84      0.84      0.83        38
# weighted avg       0.85      0.84      0.84        38

# %% [markdown]
#  **Plot the models**

# %% [markdown]
# # Appendix

# %%
# Finding important features
df1=df.drop('hull1', axis = 1)
x_train1_1 = pd.DataFrame(x_train1, columns = df1.columns)
feature_importances = pd.DataFrame(model1.feature_importances_,
                                   index = x_train1_1.columns,
                                    columns=['importance']).sort_values('importance',
                                                                        ascending=False)
feature_importances = feature_importances.round(2)
print(feature_importances.head(10))
# Out:
#               importance
# cat_gluc            0.32
# cat                 0.11
# 595.6I              0.06
# B2                  0.04
# lut_4gluc           0.03
# 1187.8I             0.03
# gallo               0.02
# 915.6II             0.02
# 595.6IV             0.02
# querc_glucII        0.02

# %%
x = df.drop(['hull1'], axis = 1) 
y= df['hull1']
x_train1, x_test1, y_train1, y_test1 = train_test_split(x,y, train_size = 0.7, test_size = 0.3, random_state = 100)
model1 = RandomForestClassifier(n_estimators = 200,min_samples_split = 12
,min_samples_leaf = 4, max_features = 40, max_depth=20, bootstrap= True)
model1.fit(x_train1, y_train1)
y_pred1 = model1.predict(x_test1)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
xs = x_train1['cat_gluc']
ys = x_train1['lut_4gluc']
zs = x_train1['gallo']
cs = y_train1
colors = {0: 'brown', 1: 'green', 2: 'grey', 3: 'tan'}
ax.scatter(xs, ys, zs, c = cs.apply(lambda x: colors[x]),
           s=50, alpha=0.8, edgecolors='w', marker = 'o')
ax.set_xlabel('Catechin glucoside', fontdict ={'fontsize' :13})
ax.set_ylabel('Luteolin glucoside', fontdict ={'fontsize' :13})
ax.set_zlabel('Gallocatechin', fontdict ={'fontsize' :13})
ax.set_title('Train', fontdict ={'fontsize' :20})
fig.savefig('train.png',  dpi=400)
fig.show()
files.download('train.png')

# %%
x = df.drop(['hull1'], axis = 1) 
y= df['hull1']
x_train1, x_test1, y_train1, y_test1 = train_test_split(x,y, train_size = 0.7, test_size = 0.3, random_state = 100)
model1 = RandomForestClassifier(n_estimators = 200,min_samples_split = 12
,min_samples_leaf = 4, max_features = 40, max_depth=20, bootstrap= True)
model1.fit(x_train1, y_train1)
y_pred1 = model1.predict(x_test1)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
xs = x_test1['cat_gluc']
ys = x_test1['lut_4gluc']
zs = x_test1['gallo']

colors = {0: 'brown', 1: 'green', 2: 'grey', 3: 'tan'}
ax.scatter(xs, ys, zs, c = pd.DataFrame(y_pred1, columns = ['s'])['s'].apply(lambda x: colors[x]),
           s=50, alpha=0.8, edgecolors='w', marker = 'o')
ax.set_xlabel('Catechin glucoside', fontdict ={'fontsize' :13})
ax.set_ylabel('Luteolin glucoside', fontdict ={'fontsize' :13})
ax.set_zlabel('Gallocatechin', fontdict ={'fontsize' :13})
ax.set_title('Test', fontdict ={'fontsize' :20})
fig.savefig('test.png',  dpi=400)
fig.show()
files.download('test.png')
